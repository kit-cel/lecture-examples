# %% [markdown]
# # Long-Term Prediction
#
# This code is provided as supplementary material of the lecture "Coding of Audiovisual Signals".
#
# This code illustrates
# * Long-term prediction (LTP)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import lfilter
import shutil
import scipy.signal as sp
from scipy.io import wavfile
import IPython.display as ipd
from pylab import rcParams
rcParams['axes.xmargin'] = 0

# %%
def audio_load(filename, sr = None):
    old_sampling_rate, x = wavfile.read(filename)
    if len(x.shape) == 2:
        x = np.squeeze(x[:,0])
    x = x/32768
    if sr is not None:
        sampling_rate = sr
        number_of_samples = round(len(x) * sampling_rate / old_sampling_rate) 
        x = sp.resample(x, number_of_samples)
    else:
        sampling_rate = old_sampling_rate
    return x, sampling_rate

# %%
def audio_display_waveshow(y, sr, alpha = 0.8, color = 'skyblue', linewidth = 1):
    time = np.linspace(0, len(y) / sr, num=len(y))
    #plt.plot(time, y, color=color, alpha=alpha, linewidth=1)
    #plt.xlim(time[0], time[-1])
    fig, ax = plt.subplots(figsize=(14, 4))
    ax.fill_between(time, -np.abs(y), np.abs(y), color='skyblue')
    plt.xlabel("Time")

# %% [markdown]
# Compute frequeny response of the long-term predictor
# $$
# 1-P(\mathrm{e}^{\mathrm{j}\Omega}) = \sqrt{(1-b\cdot\cos(N_0\Omega))^2 + b^2\cdot\sin^2(N_0\Omega)}\cdot\mathrm{e}^{-\mathrm{j}\phi_P(\Omega)}
# $$
# with
# $$
# \phi_P(\Omega) = -\arctan\left(\frac{b\cdot \sin(N_0\Omega)}{1-b\cos(N_0\Omega)}\right)
# $$

# %%
def get_LTP_Frequency_Response(Omega, N0, b):    
    phi_P = -np.arctan2(b*np.sin(N0*Omega), 1-b*np.cos(N0*Omega))
    return np.sqrt(np.square((1-b*np.cos(N0*Omega))) + np.square(b*np.sin(N0*Omega))) *np.exp(-1j * phi_P)    

Omega = np.linspace(0,np.pi,10000)


N0 = 100
LTP_Freqb1 = get_LTP_Frequency_Response(Omega, N0, 1)
LTP_Freqb08 = get_LTP_Frequency_Response(Omega, N0, 0.8)

# %% [markdown]
# Plot frequency response

# %%
font = {'size'   : 18}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)

plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
plt.plot(Omega, np.abs(LTP_Freqb1), lw=2)
plt.xlim((0,2*np.pi/N0*8))
plt.ylim((0,2.2))
plt.xticks([2*np.pi/N0], labels=[r'$\frac{2\pi}{N_0}$'])
plt.xlabel(r'$\Omega$')
plt.ylabel(r'$|1-P(\mathrm{e}^{\mathrm{j}\Omega})|$')
plt.title('$b=1$')
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(Omega, np.abs(LTP_Freqb08), lw=2)
plt.xlim((0,2*np.pi/N0*8))
plt.ylim((0,2.2))
plt.xticks([2*np.pi/N0], labels=[r'$\frac{2\pi}{N_0}$'])
plt.xlabel(r'$\Omega$')
plt.ylabel(r'$|1-P(\mathrm{e}^{\mathrm{j}\Omega})|$')
plt.title('$b=0.8$')
plt.grid(True)

plt.tight_layout()
#plt.savefig('figure_DST_6.15bc.pdf', bbox_inches='tight')

# %% [markdown]
# ---
# Illustrate long-term prediction on a short speech segment

# %%
wave_filename = 'speech_segment.wav'

# load file, do *not* resample
x, sampling_rate = audio_load(wave_filename)

# time in ms
t = np.arange(len(x)) / sampling_rate * 1000.0

# %%
# helper function calculating the auto-correlation coefficient r
def get_r(x, l):    
    x_shift = np.roll(x,l)
    x_shift[:l] = 0        
    return np.correlate(x,x_shift)[0]
    
def get_s(x, l):
    x_shift = np.roll(x,l)
    x_shift[:l] = 0        
    return np.correlate(x_shift,x_shift)[0]
    
def get_prediction_coefficients(x, n):
    r = np.array([get_r(x,k) for k in np.arange(1,n+1)])
    R = np.array([np.concatenate(([get_r(x,j) for j in np.arange(i,0,-1)], [get_r(x,j) for j in np.arange(0,n-i)])) for i in range(n)])    
    
    a_opt = np.linalg.inv(R) @ r
    return a_opt

def get_prediction_frequency_response(a, Omega):    
    A = np.ones_like(Omega) + 1j*np.zeros_like(Omega)
    for k in range(len(a)):
        A -= a[k] * np.exp(-1j*(k+1)*Omega)
    return A

# %%
# short-term prediction
n = 8
a = get_prediction_coefficients(x, n)
xh = lfilter(np.concatenate(([0], a)), 1, x)

d = x - xh
print(len(x))
# Out:
# 660

# %%
# find optimal N0 and b
# sweep values
N0_range= np.arange(10,160)
N0_cost = np.zeros_like(N0_range, dtype=float)

for idx,value in enumerate(N0_range):
    N0_cost[idx] = get_s(d, 0) - (get_r(d, value)**2)/get_s(d, value)
    
N0 = N0_range[np.argmin(N0_cost)]

# if we have N0, get b
b = get_r(d, N0)/get_s(d, N0)

# %%
# apply long term prediction
dh = lfilter(np.concatenate((np.zeros(N0), [b])), 1, d)

dtilde = d - dh

# %%
font = {'size'   : 18}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)

plt.figure(figsize=(12, 10))
plt.subplot(3,1,1)
plt.plot(t, x)
plt.xlim((30,t[-1]))
plt.ylim((-1,1))
plt.xlabel(r'$k\cdot T$ (ms)')
plt.ylabel('$x[k]$')

plt.subplot(3,1,2)
plt.plot(t, d)
plt.xlim((30,t[-1]))
plt.ylim((-1,1))
plt.xlabel(r'$k\cdot T$ (ms)')
plt.ylabel('$d[k]$')
r
plt.subplot(3,1,3)
plt.plot(t, dtilde)
plt.xlim((30,t[-1]))
plt.ylim((-1,1))
plt.xlabel(r'$k\cdot T$ (ms)')
plt.ylabel(r'$\tilde{d}[k]$')

plt.tight_layout()
#plt.savefig('figure_DST_6.16b.pdf', bbox_inches='tight')

# %% [markdown]
# Plot spectra

# %%
X = np.fft.fft(x, 1024)
G = get_prediction_frequency_response(a, Omega)
D = np.fft.fft(d, 1024)
P = 1-get_LTP_Frequency_Response(Omega, N0, b)
Dt= np.fft.fft(dtilde, 1024)

# %%
font = {'size'   : 18}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)

plt.figure(figsize=(8, 14))
plt.subplot(5,1,1)
plt.plot(np.linspace(0,sampling_rate/2,len(X)//2),np.abs(X[:(len(X)//2)]), color='xkcd:orange', lw=2)
plt.xlim((0,sampling_rate/2))
plt.ylim((0,65))
plt.xlabel('$f$ (kHz)')
plt.ylabel(r'$|X(\mathrm{e}^{\mathrm{j}\Omega})|$')

plt.subplot(5,1,2)
plt.plot(np.linspace(0,sampling_rate/2,len(Omega)),np.abs(G), color='xkcd:blue', lw=2)
plt.xlim((0,sampling_rate/2))
plt.ylim((0,8))
plt.xlabel('$f$ (kHz)')
plt.ylabel(r'$|1-A(\mathrm{e}^{\mathrm{j}\Omega})|$')

plt.subplot(5,1,3)
plt.plot(np.linspace(0,sampling_rate/2,len(D)//2),np.abs(D[:(len(X)//2)]), color='xkcd:orange', lw=2)
plt.xlim((0,sampling_rate/2))
plt.ylim((0,60))
plt.xlabel('$f$ (kHz)')
plt.ylabel(r'$|D(\mathrm{e}^{\mathrm{j}\Omega})|$')

plt.subplot(5,1,4)
plt.plot(np.linspace(0,sampling_rate/2,len(Omega)),np.abs(1-P), color='xkcd:teal', lw=2)
plt.xlim((0,sampling_rate/2))
plt.ylim((0,2))
plt.xlabel('$f$ (kHz)')
plt.ylabel(r'$|D(\mathrm{e}^{\mathrm{j}\Omega})|$')

plt.subplot(5,1,5)
plt.plot(np.linspace(0,sampling_rate/2,len(Dt)//2),np.abs(Dt[:(len(X)//2)]), color='xkcd:orange', lw=2)
plt.xlim((0,sampling_rate/2))
plt.ylim((0,60))
plt.xlabel('$f$ (kHz)')
plt.ylabel(r'$|\tilde{D}(\mathrm{e}^{\mathrm{j}\Omega})|$')

plt.tight_layout()
#plt.savefig('figure_DST_6.17_part.pdf', bbox_inches='tight')

# %% [markdown]
# Audio example.

# %%
wave_filename = '../audio/33711__acclivity__excessiveexposure.wav'

# %%
# block prediction with N samples per block and predictor order n
def block_prediction_with_LTP(x, n, N):
    if n==0:
        return x
    
    frames = int(np.floor(len(x) / N))

    # prediction error
    d = np.zeros_like(x)

    # long-term prediction error
    d_LTP = np.zeros_like(x)
    
    # no adaptation for first frame
    a = np.zeros(n)

    # filter memory
    memory = np.zeros(n)        

    d_part_old = np.zeros(N)
    
    for k0 in range(frames):
        x_part = x[np.arange(N)+k0*N]

        # compute prediction coefficients on current block
        a = get_prediction_coefficients(x_part, n)               
        
        xh_part, memory = lfilter(np.concatenate(([0], a)), 1, x_part, zi=memory)
        d_part = x_part - xh_part
        d[np.arange(len(xh_part)) + k0*N] = d_part
        
        # find best N0
        for idx,value in enumerate(N0_range):
            N0_cost[idx] = get_s(d_part, 0) - (get_r(d_part, value)**2)/get_s(d_part, value)
    
        N0 = N0_range[np.argmin(N0_cost)]

        # if we have N0, get b
        b = get_r(d_part, N0)/get_s(d_part, N0)
        
        # apply LTP
        dh_part,_ = lfilter(np.concatenate((np.zeros(N0), [b])), 1, d_part, zi=d_part_old[-N0:])
        d_LTP[np.arange(len(dh_part)) + k0*N] = d_part - dh_part
        
        d_part_old = d_part
    return d,d_LTP

# %%
# Load file with a sampling rate of 8KHz
x, sampling_rate = audio_load(wave_filename, sr = 8000)
# carry out prediction on 20ms blocks
N = int(sampling_rate * 0.02)

# prediction with 15 predictor coefficients
d,dtilde = block_prediction_with_LTP(x, 15, N)

# %% [markdown]
# Play original file

# %%
ipd.Audio(x, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Play prediction error after linear prediction

# %%
ipd.Audio(d, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Play prediction error after long-term prediction

# %%
ipd.Audio(dtilde, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x_max = np.max([np.max(x), -np.min(x)])

plt.figure(figsize=(10, 11))
#plt.subplot(3,1,1)
audio_display_waveshow(x, sr=sampling_rate)
plt.title('Original')
plt.ylim((-x_max*1.2,+x_max*1.2))
#plt.subplot(3,1,2)
audio_display_waveshow(d, sr=sampling_rate)
plt.title('Predicted error after short-term prediction')
plt.ylim((-x_max*1.2,+x_max*1.2))
#plt.subplot(3,1,3)
audio_display_waveshow(dtilde, sr=sampling_rate)
plt.title('Predicted error after short-term and long-term prediction')
plt.ylim((-x_max*2.2,+x_max*2.2))
plt.tight_layout()
