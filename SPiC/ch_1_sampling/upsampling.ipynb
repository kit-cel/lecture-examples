# %% [markdown]
# # Content and Objective
#
# + Show effects of upsampling by artificially increasing sampling frequency
# + Show interpolation by using lowpass filtering

# %% [markdown]
# # Importing and Plotting Options

# %%
import numpy as np

from scipy import signal

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# plotting options 
font = {'size'   : 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)

matplotlib.rc('figure', figsize=(18, 6) )

# %% [markdown]
# # Parameters

# %%
# define parameters
t_min = 0.0
t_max = 10.0    

# sampling time and Nyquist frequency 
t_s = .25
f_Nyquist = 1 / (2.0 * t_s )

# %% [markdown]
# # Sampled signal and spectra

# %%
# get time vector, define signal and normalize
t_samp = np.arange( t_min, t_max, t_s)

x_samp = ( signal.gausspulse( t_samp-3, 1, retenv=1))[1] 
x_samp = x_samp * np.sqrt( 1 / sum(x_samp**2) )

# determine according Nyquist band and fft
f_samp = np.arange( -f_Nyquist, f_Nyquist, 1/(t_max-t_min) )    

X_samp = np.fft.fftshift( np.fft.fft( x_samp ) )

# %% [markdown]
#  # Perform upsampling

# %%
# upsampling
M = 4
t_s_up = t_s / M
t_up = np.arange(t_min, t_max, t_s_up)

# upsample signal by factor M using lambda function
x_up = np.zeros( M * len(x_samp) )
x_up[ :: M ] = x_samp

# determine according Nyquist band and fft
f_Nyquist_up = 1 / ( t_s_up * 2.0 )
f_up = np.arange( -f_Nyquist_up, f_Nyquist_up, 1/(t_max-t_min) )    
X_up = np.fft.fftshift( np.fft.fft(x_up) )

# %%
# apply ideal filtering to the upsampled sequence
X_up_f_i = np.copy( X_up )

ind_Nyquist = np.argwhere( abs(f_up) > f_Nyquist ) 
X_up_f_i[ ind_Nyquist ] = 0

x_up_f_i = np.fft.ifft( np.fft.fftshift( X_up_f_i ) )
    
   
# apply "real-world" filtering
cutoff_freq = f_Nyquist / 2

ripple_db = 30                      # ripples and transition width of the filter
width = f_Nyquist / 60.0

N, beta = signal.kaiserord(ripple_db, width)    # find filter order and beta parameter

# find filter and filter input
taps = signal.firwin( N, cutoff_freq,  width=width, window=('kaiser', beta), pass_zero='lowpass', fs = f_Nyquist_up)

x_up_f_k = signal.lfilter( taps, 1.0, x_up)
X_up_f_k = np.fft.fftshift( np.fft.fft(x_up_f_k) )


# impulse and frequency response of the filter
w, H = signal.freqz( taps )
h = taps
print(N)
# Out:
# 94

# %% [markdown]
# # Plotting results

# %%
plt.figure(1)

plt.subplot(321)
plt.plot(t_samp, x_samp, 'o', markersize=10, label='$x[n]$')
plt.grid(True)
plt.axis(xmin=0, xmax=6, ymin=-.1, ymax=.5)    
plt.xlabel('$t/\mathrm{s}$')
plt.legend(loc='upper right')

plt.subplot(323)
plt.plot(t_up, x_up, 'x', markersize=10, label='$x_\\mathrm{up}[n]$')
plt.grid(True)
plt.axis(xmin=0, xmax=6, ymin=-.1, ymax=.5)    
plt.xlabel('$t/\mathrm{s}$')
plt.legend(loc='upper right')

plt.subplot(325)
plt.plot(t_up, x_up_f_i, 'x', markersize=10, label='$x_\\mathrm{up,filtered}[n]$')
plt.grid(True)
plt.axis(xmin=0, xmax=6, ymin=-.1, ymax=.5)    
plt.xlabel('$t/\mathrm{s}$')
plt.legend(loc='upper right')

plt.subplot(322)        
plt.plot(f_samp, abs(X_samp)**2, '-o', markersize=10, label='$|X[k]|^2$')
plt.grid(True)
plt.xlabel('$f/\mathrm{Hz}$')
#plt.ylabel('$|X[k]|^2$')
plt.legend(loc='upper right')

plt.subplot(324)        
plt.plot(f_up, abs(X_up)**2, '', label='$|X_\\mathrm{up}(f)|^2$')
plt.grid(True)
plt.xlabel('$f/\mathrm{Hz}$')
#plt.ylabel('$|X[k]|^2$')
plt.annotate('Nyquist spectrum',
        xy=(0,10.5),
        xytext=(2,12),
        arrowprops={'facecolor':'green','shrink':0.05},
        )    
plt.annotate('Images',
        xy=(-4,10.5),
        xytext=(-7,12),
        arrowprops={'facecolor':'green','shrink':0.05},
        )  
plt.legend(loc='upper right')

plt.subplot(326)        
plt.plot(f_up, abs(X_up_f_i)**2, '', label='$|X_\\mathrm{up,filtered}(f)|^2$')
plt.grid(True)
plt.xlabel('$f/\mathrm{Hz}$')
#plt.ylabel('$|X[k]|^2$')
plt.legend(loc='upper right')

plt.subplots_adjust(left=0.1, right=1.0, 
                    top=2.0, bottom=0.3, 
                    wspace=0.1, hspace=0.4)

plt.figure(2)

plt.subplot(121)
plt.plot(t_up, x_up_f_i,'o',label='$x_\\mathrm{ideal}[n]$')
plt.plot(t_up, x_up_f_k,'o',label='$x_\\mathrm{FIR}[n]$')
plt.grid(True)
plt.axis(xmin=0, xmax=6, ymin=-.1, ymax=.5)    
plt.xlabel('$t/\mathrm{s}$')
plt.legend(loc='upper right')           

plt.subplot(122)        
plt.plot(f_up, abs(X_up_f_i)**2, '-o', label='$X(f)$')
plt.plot(f_up, abs(X_up_f_k)**2, '-o')
plt.grid(True)
plt.legend(loc=0)   
plt.xlabel('$f/\mathrm{Hz}$')
plt.legend(loc='upper right')      


plt.figure(3)

plt.subplot(121)
plt.plot(np.arange(0, len(h)), h, 'o' , markersize=10, label='$h[n]$')
plt.grid(True)
plt.xlabel('$n$')
#plt.ylabel('$h[n]$')
plt.legend(loc='upper right')      

plt.subplot(122)        
plt.plot(w, 10*np.log10(abs(H)**2), label='$|H(f)|^2$')
plt.grid(True)
plt.xlabel('$f/\mathrm{Hz}$')
#plt.ylabel('$|H(f)|^2 (dB)$')
plt.legend(loc='upper right')  

plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:34: SyntaxWarning: invalid escape sequence '\m'
# <>:51: SyntaxWarning: invalid escape sequence '\m'
# <>:66: SyntaxWarning: invalid escape sequence '\m'
# <>:74: SyntaxWarning: invalid escape sequence '\m'
# <>:90: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:27: SyntaxWarning: invalid escape sequence '\m'
# <>:34: SyntaxWarning: invalid escape sequence '\m'
# <>:51: SyntaxWarning: invalid escape sequence '\m'
# <>:66: SyntaxWarning: invalid escape sequence '\m'
# <>:74: SyntaxWarning: invalid escape sequence '\m'
# <>:90: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:7: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$t/\mathrm{s}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:14: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$t/\mathrm{s}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$t/\mathrm{s}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:27: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$f/\mathrm{Hz}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:34: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$f/\mathrm{Hz}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:51: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$f/\mathrm{Hz}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:66: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$t/\mathrm{s}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:74: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$f/\mathrm{Hz}$')
# /var/folders/g2/fvqz4zn95nd7kbhf6wdgn2dc0000gn/T/ipykernel_23861/3419618448.py:90: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$f/\mathrm{Hz}$')
# /Users/jaekel/miniconda3/envs/python_3_13/lib/python3.13/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/jaekel/miniconda3/envs/python_3_13/lib/python3.13/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
