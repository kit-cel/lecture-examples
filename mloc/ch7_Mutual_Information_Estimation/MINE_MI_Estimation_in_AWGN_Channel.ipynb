# %% [markdown]
# # MINE Mutual Information Estimation in Zero-Dispersion Optical Channel
#
# This code is provided as supplementary material of the lecture Machine Learning and Optimization in Communications (MLOC).<br>
#
# This code illustrates
# * Using the MINE mutual information estimator to compute the achievable information rate (AIR) of the channel

# %%
import torch
import copy
import shutil
import torch.nn as nn
import torch.optim as optim
import numpy as np

import matplotlib.pyplot as plt
from ipywidgets import IntProgress
from IPython.display import display

# %matplotlib inline 

# Search for a GPU and use CUDA if available, Apple Silicon (MPS) if present, otherwise CPU.
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if getattr(torch.backends, "mps", None) and torch.backends.mps.is_available() else "cpu")
print("We are using the following device for learning:",device)
# Out:
# We are using the following device for learning: cuda

# %% [markdown]
# Simple real-valued AWGN channel, with channel output $r_i = t_i + n_i$ where $\mathsf{n} \sim \mathcal{N}(0,\sqrt{N_0/(2E_{\mathrm{s}})})$. Note that we define $E_{\mathrm{s}}/N_0$ as if we had a complex-valued channel of which we only use the real-part.

# %%
def simulate_channel(x, EsN0):      
    EsN0_lin = 10**(EsN0/10.0)
    sigma = np.sqrt(1.0/2.0/EsN0_lin)
    
    y = x + sigma * np.random.randn(len(x))
    
    return x,y

# %% [markdown]
# The MINE estimator [1] uses the Donsker-Varadhan variational represention of the mutual information, which is given by
# $$
# I(\mathsf{t};\mathsf{r}) = \sup_{f:\mathcal{T}\times\mathcal{R}\to\mathbb{R}}\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t},\mathsf{r})}\{f(\mathsf{t},\mathsf{r})\} - \log\left(\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\left\{\mathrm{e}^{f(\mathsf{t},\mathsf{r})}\right\}\right)
# $$
# where $f:\mathcal{T}\times\mathcal{R}\to\mathbb{R}$ is any function that maps input and output of the channel to a scalar value. The maximization ("$\sup$") needs to be carried out over all such functions. In this example, we use a neural network to approximate this variational function. The neural network is implemented in the next block and consists of two hidden layers with ELU activation function. We need to make sure that the function is numerically stable and therefore use an initializer for the initial weights with very small variance.
#
# [1] M. Belghazi, A. Baratin, S. Rajeswar, S. Ozair, Y. Bengio, A. Courville, and R. D. Hjelm, "MINE: Mutual information
# neural estimation," __Proc. ICML__, preprint available at \url{https://arxiv.org/abs/1801.04062}, 2018

# %%
class Variational_Function(nn.Module):
    def __init__(self, hidden_neurons_1, hidden_neurons_2):
        super(Variational_Function, self).__init__()
        
        # Linear function, 2 input neurons (channel input and channel output)
        self.fc1 = nn.Linear(2, hidden_neurons_1) 

        # Non-linearity
        self.activation_function = nn.ELU()           
    
        # Linear function (hidden layer)
        self.fc2 = nn.Linear(hidden_neurons_1, hidden_neurons_2)  

        # Output layer generating a scalar
        self.fc3 = nn.Linear(hidden_neurons_2, 1)
                
        # initialize weights of layers
        nn.init.normal_(self.fc1.weight, std=0.02)
        nn.init.constant_(self.fc1.bias, 0)
        nn.init.normal_(self.fc2.weight, std=0.02)
        nn.init.constant_(self.fc2.bias, 0)
        nn.init.normal_(self.fc3.weight, std=0.02)
        nn.init.constant_(self.fc3.bias, 0)
        
    def forward(self, x):
        # Linear function, first layer
        out = self.fc1(x)

        # Non-linearity, first layer
        out = self.activation_function(out)
        
        # Linear function, second layer
        out = self.fc2(out)
        
        # Non-linearity, second layer
        out = self.activation_function(out)                
        
        # Linear function, output layer
        out = self.fc3(out)

        return out

# %% [markdown]
# Carry out the final optimization. We use the Adam algorithm with small learning rate and use a modification of the cost function, which leads to a more stable estimator.
#
# Let $J(\boldsymbol{t}, \boldsymbol{r}, \boldsymbol{\theta})$ be the loss function. Then we exploit the fact that with
# $$
# J(\boldsymbol{t}, \boldsymbol{r}, \boldsymbol{\theta}) := \mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t},\mathsf{r})}\{f(\mathsf{t},\mathsf{r})\} - \log\left(\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\left\{\mathrm{e}^{f(\mathsf{t},\mathsf{r})}\right\}\right)
# $$ we have
# \begin{align*}
# \nabla_{\boldsymbol{\theta}}J(\boldsymbol{t}, \boldsymbol{r}, \boldsymbol{\theta}) &= \nabla_{\boldsymbol{\theta}}\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t},\mathsf{r})}\{f(\mathsf{t},\mathsf{r})\} - \frac{\nabla_{\boldsymbol{\theta}}\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\left\{\mathrm{e}^{f(\mathsf{t},\mathsf{r})}\right\}}{\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\left\{\mathrm{e}^{f(\mathsf{t},\mathsf{r})}\right\}}
# \end{align*}
# Applying stochastic gradient descent over the batch with $N$ examples yields
# \begin{align*}
# \nabla_{\boldsymbol{\theta}}J(\boldsymbol{t}, \boldsymbol{r}, \boldsymbol{\theta}) &\approx \frac{1}{N}\sum_{i=1}^N\nabla_{\boldsymbol{\theta}}f(t_i,r_i) - \frac{\frac{1}{N}\sum_{i=1}^N\nabla_{\boldsymbol{\theta}}\mathrm{e}^{f(t_i,\tilde{r}_i)}}{\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\left\{\mathrm{e}^{f(\mathsf{t},\mathsf{r})}\right\}}
# \end{align*}
# where $r_i$ is the result of transmitting $t_i$ over the channel and $\tilde{r}_i$ is the result of transmitting $\tilde{t}_i$ over the channel, where we discard the transmit sequence $\tilde{t}_i$. This needs to be done to ensure that the expectation is taken over the product of marginal distributions ($\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\{\cdot\}$). For details, see [1].
#
# In the denominator of the approximated gradient, we have the term $\mathbb{E}_{\mathsf{t},\mathsf{r}\sim p(\mathsf{t})p(\mathsf{r})}\left\{\mathrm{e}^{f(\mathsf{t},\mathsf{r})}\right\}$. We estimate this term using a moving average over the mini-batches. We need to make sure that this term is not taken into account when calculating the gradient, which is done using the `.detach()` function. The original loss function is also available in the code below as a comment.

# %% [raw]
# EsN0 = 0.0
#
# MI_reference = 0.5*np.log2(1 + 2 * 10.0**(EsN0/10.0))
#
# hidden_neurons_1 = 50
# hidden_neurons_2 = 30
#
#
# # Generate variational function
# model = Variational_Function(hidden_neurons_1, hidden_neurons_2)
# model.to(device)
#
# # Adam Optimizer
# optimizer = optim.Adam(model.parameters())
#
# num_epochs = 100
# batches_per_epoch = 200
#
# # increase batch size while learning from 100 up to 10000
# batch_size_per_epoch = np.linspace(400, 20000, num=num_epochs, dtype=int)
#
# ma_et = 0.0
# best_MI = -np.inf
# best_epoch = 0
#
#
# for epoch in range(num_epochs):
#     for step in range(batches_per_epoch):
#
#
#         t,r = simulate_channel(np.random.randn(batch_size_per_epoch[epoch]), EsN0)
#         _,rtilde = simulate_channel(np.random.randn(batch_size_per_epoch[epoch]), EsN0)
#
#         model.train()
#
#         # generate input to first call of the variational function
#         input_1 = np.vstack( (t, r) ).transpose()
#         torch_in1 = torch.from_numpy(input_1).float().to(device)
#
#         # generate input to second call of the variational function
#         input_2 = np.vstack( (t, rtilde) ).transpose()
#         torch_in2 = torch.from_numpy(input_2).float().to(device)
#
#         # apply the variational function
#         out_1 = model(torch_in1)
#         out_2 = model(torch_in2)
#
#
#         # loss function. Attenation, put a minus sign as we want to maximize
#         loss = -torch.mean(out_1) + torch.log(torch.mean(torch.exp(out_2)))
#
#         #tmp = torch.exp(out_2)
#         #ma_et = (1.0-0.05)*ma_et + 0.05*torch.mean(tmp.detach())
#         #loss = -torch.mean(out_1) + (1/ma_et.mean()).detach() * torch.mean(tmp)
#
#         # compute gradients
#         loss.backward()
#
#         # carry out one optimization step with Adam
#         optimizer.step()
#
#         # reset gradients to zero
#         optimizer.zero_grad()
#
#     model.eval()
#     t,r = simulate_channel(np.random.randn(10000), EsN0)
#     _,rtilde = simulate_channel(np.random.randn(10000), EsN0)
#
#
#     # generate input to first call of the variational function
#     input_1 = np.vstack( (t,r) ).transpose()
#     torch_in1 = torch.from_numpy(input_1).float().to(device)
#
#     # generate input to second call of the variational function
#     input_2 = np.vstack( (t,rtilde) ).transpose()
#     torch_in2 = torch.from_numpy(input_2).float().to(device)
#
#     # apply the variational function
#     out_1 = model(torch_in1)
#     out_2 = model(torch_in2)
#
#     # loss function. Attenation, put a minus sign as we want to maximize
#     MI_eval = torch.mean(out_1) - torch.log2(torch.mean(torch.pow(2.0, out_2)))
#     current_MI = MI_eval.item()
#     if current_MI > best_MI:
#         best_model_state_dict = copy.deepcopy(model.state_dict())
#         best_MI = current_MI
#         best_epoch = epoch
#         print('Epoch %d: current MI estimate is %1.3f bit/channel use (reference: %1.3f bit/channel use) ... SAVING' % (epoch, current_MI, MI_reference))
#     else:
#         print('Epoch %d: current MI estimate is %1.3f bit/channel use (reference: %1.3f bit/channel use)' % (epoch, current_MI, MI_reference))
#
# model.load_state_dict(best_model_state_dict)

# %% [markdown]
# Show the convergence of the training

# %%
EsN0 = 5.0

MI_reference = 0.5*np.log2(1 + 2 * 10.0**(EsN0/10.0))

hidden_neurons_1 = 100
hidden_neurons_2 = 100


# Generate variational function
model = Variational_Function(hidden_neurons_1, hidden_neurons_2)
model.to(device)

# Adam Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.0001)  

num_epochs = 1000
batches_per_epoch = 2

# increase batch size while learning from 100 up to 10000
batch_size_per_epoch = np.linspace(10000, 10000, num=num_epochs, dtype=int)

ma_et = 0.0

# Progress bar
f = IntProgress(min=0, max=num_epochs) # instantiate the bar
display(f) # display the bar

MI_eval = np.zeros(num_epochs)
best_MI = -np.inf
best_epoch = 0
for epoch in range(num_epochs):
    for step in range(batches_per_epoch):
        
        
        t,r = simulate_channel(np.random.randn(batch_size_per_epoch[epoch]), EsN0)
        _,rtilde = simulate_channel(np.random.randn(batch_size_per_epoch[epoch]), EsN0)
        
        model.train()
                
        # generate input to first call of the variational function
        input_1 = np.vstack( (t, r) ).transpose()
        torch_in1 = torch.from_numpy(input_1).float().to(device)
        
        # generate input to second call of the variational function
        input_2 = np.vstack( (t, rtilde) ).transpose()
        torch_in2 = torch.from_numpy(input_2).float().to(device)
        
        # apply the variational function
        out_1 = model(torch_in1)
        out_2 = model(torch_in2)
        
        
        # loss function. Attenation, put a minus sign as we want to maximize
        loss = -torch.mean(out_1) + torch.log(torch.mean(torch.exp(out_2)))
        
        #tmp = torch.exp(out_2)
        #ma_et = (1.0-0.1)*ma_et + 0.1*torch.mean(tmp.detach())        
        #loss = -torch.mean(out_1) + (1/ma_et.mean()).detach() * torch.mean(tmp)               
                
        # compute gradients
        loss.backward() 
        
        # carry out one optimization step with Adam
        optimizer.step()
        
        # reset gradients to zero
        optimizer.zero_grad()
        
    model.eval()
    t,r = simulate_channel(np.random.randn(10000), EsN0)
    _,rtilde = simulate_channel(np.random.randn(10000), EsN0)
        
        
    # generate input to first call of the variational function
    input_1 = np.vstack( (t,r) ).transpose()
    torch_in1 = torch.from_numpy(input_1).float().to(device)
        
    # generate input to second call of the variational function
    input_2 = np.vstack( (t,rtilde) ).transpose()
    torch_in2 = torch.from_numpy(input_2).float().to(device)
        
    # apply the variational function
    out_1 = model(torch_in1)
    out_2 = model(torch_in2)
        
    # loss function. Attenation, put a minus sign as we want to maximize
    MI_eval[epoch] = (torch.mean(out_1) - torch.log2(torch.mean(torch.pow(2.0, out_2)))).cpu().detach().numpy()
    #print('Epoch %d: current MI estimate is %1.3f bit/channel use ... SAVING' % (epoch, MI_eval[epoch]))
    f.value += 1
    #print('Epoch %d: current MI estimate is %1.3f bit/channel use (reference: %1.3f bit/channel use)' % (epoch, MI_eval.cpu().detach().numpy(), MI_reference) )
# Out:
# IntProgress(value=0, max=1000)

# %%
# plotting options 
import matplotlib
font = {'size'   : 15}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)

plt.figure(figsize=(7,5))
plt.plot(np.arange(num_epochs)*2, MI_reference * np.ones(num_epochs))
plt.plot(np.arange(num_epochs)*2, MI_eval)
plt.xlim((0,2000))
plt.ylim((0,1.5))
plt.grid(True)
plt.legend([r'${I}(\mathsf{r};\mathsf{t}) = \frac{1}{2} \log_2\left(1+2\frac{E_{\mathrm{s}}}{N_0}\right)$','MINE'])
plt.title('Convergence of MINE');
plt.xlabel('Batch')
plt.ylabel(r'$\\hat{I}(\mathsf{r};\mathsf{t})$ (bit/channel use)')

#plt.savefig('MINE_Convergence.pdf',bbox_inches='tight')
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_1111/270490235.py:16: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$\\hat{I}(\mathsf{r};\mathsf{t})$ (bit/channel use)')
# Text(0, 0.5, '$\\hat{I}(\\mathsf{r};\\mathsf{t})$ (bit/channel use)')

# %% [markdown]
# Now we train a GMM for each constellation point individually. We will use this one to compute the mutual information (and hence the performance of a transmission scheme) later

# %%
def MINE_getMI_AWGN(EsN0):
    # Generate variational function
    model = Variational_Function(hidden_neurons_1, hidden_neurons_2)
    model.to(device)

    # Adam Optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.0001)  

    num_epochs = 100
    batches_per_epoch = 250

    # increase batch size while learning from 100 up to 10000
    batch_size_per_epoch = np.linspace(400, 20000, num=num_epochs, dtype=int)

    ma_et = 0;
    MI_eval = np.zeros(num_epochs)
    best_MI = -np.inf
    best_epoch = 0
    
    for epoch in range(num_epochs):
        for step in range(batches_per_epoch):
            t,r = simulate_channel(np.random.randn(batch_size_per_epoch[epoch]), EsN0)
            _,rtilde = simulate_channel(np.random.randn(batch_size_per_epoch[epoch]), EsN0)

            model.train()

            # generate input to first call of the variational function
            input_1 = np.vstack( (t, r) ).transpose()
            torch_in1 = torch.from_numpy(input_1).float().to(device)

            # generate input to second call of the variational function
            input_2 = np.vstack( (t, rtilde) ).transpose()
            torch_in2 = torch.from_numpy(input_2).float().to(device)

            # apply the variational function
            out_1 = model(torch_in1)
            out_2 = model(torch_in2)


            # loss function. Attenation, put a minus sign as we want to maximize
            loss = -torch.mean(out_1) + torch.log(torch.mean(torch.exp(out_2)))
            #tmp = torch.exp(out_2)
            #ma_et = (1.0-0.05)*ma_et + 0.05*torch.mean(tmp.detach())        
            #loss = -torch.mean(out_1) + (1/ma_et.mean()).detach() * torch.mean(tmp.detach() * out_2)       

            # compute gradients
            loss.backward() 

            # carry out one optimization step with Adam
            optimizer.step()

            # reset gradients to zero
            optimizer.zero_grad()
        
        model.eval()
        t,r = simulate_channel(np.random.randn(100000), EsN0)
        _,rtilde = simulate_channel(np.random.randn(100000), EsN0)


        # generate input to first call of the variational function
        input_1 = np.vstack( (t,r) ).transpose()
        torch_in1 = torch.from_numpy(input_1).float().to(device)

        # generate input to second call of the variational function
        input_2 = np.vstack( (t,rtilde) ).transpose()
        torch_in2 = torch.from_numpy(input_2).float().to(device)

        # apply the variational function
        out_1 = model(torch_in1)
        out_2 = model(torch_in2)

        # Obtain mutual information
        MI_eval[epoch] = (torch.mean(out_1) - torch.log2(torch.mean(torch.pow(2.0, out_2)))).cpu().detach().numpy()
        if MI_eval[epoch] > best_MI:
            best_model_state_dict = copy.deepcopy(model.state_dict())
            best_MI = MI_eval[epoch]
            best_epoch = epoch
            print('Epoch %d: current MI estimate is %1.3f bit/channel use ... SAVING' % (epoch, MI_eval[epoch]))

    model.load_state_dict(best_model_state_dict)
    return best_MI

# %% [markdown]
# Show performance over a range of $E_{\mathrm{s}}/N_0$.

# %%
num_elements = 10
esno_range = np.linspace(-10,10, num_elements)


f = IntProgress(min=0, max=num_elements) # instantiate the bar
display(f) # display the bar

MI_ref = np.zeros(num_elements)
MI_MINE = np.zeros(num_elements)

for i,esno in enumerate(esno_range):
    MI_ref[i] = 0.5*np.log2(1 + 2 * 10.0**(esno/10.0))
    MI_MINE[i] = MINE_getMI_AWGN(esno)
    
    # increase progress bar
    f.value += 1
# Out:
# IntProgress(value=0, max=10)
# Epoch 0: current MI estimate is 0.000 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.026 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.114 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 0.118 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 0.121 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.000 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.054 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.186 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 0.188 bit/channel use ... SAVING
# Epoch 7: current MI estimate is 0.189 bit/channel use ... SAVING
# Epoch 15: current MI estimate is 0.192 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.001 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.115 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.283 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 0.291 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 0.292 bit/channel use ... SAVING
# Epoch 13: current MI estimate is 0.295 bit/channel use ... SAVING
# Epoch 19: current MI estimate is 0.295 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.001 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.117 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.403 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 0.426 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 0.428 bit/channel use ... SAVING
# Epoch 6: current MI estimate is 0.430 bit/channel use ... SAVING
# Epoch 8: current MI estimate is 0.431 bit/channel use ... SAVING
# Epoch 9: current MI estimate is 0.434 bit/channel use ... SAVING
# Epoch 12: current MI estimate is 0.438 bit/channel use ... SAVING
# Epoch 13: current MI estimate is 0.441 bit/channel use ... SAVING
# Epoch 17: current MI estimate is 0.447 bit/channel use ... SAVING
# Epoch 19: current MI estimate is 0.448 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.002 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.178 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.516 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 0.611 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 0.629 bit/channel use ... SAVING
# Epoch 6: current MI estimate is 0.631 bit/channel use ... SAVING
# Epoch 11: current MI estimate is 0.633 bit/channel use ... SAVING
# Epoch 18: current MI estimate is 0.637 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.002 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.205 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.684 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 0.832 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 0.854 bit/channel use ... SAVING
# Epoch 7: current MI estimate is 0.858 bit/channel use ... SAVING
# Epoch 10: current MI estimate is 0.860 bit/channel use ... SAVING
# Epoch 12: current MI estimate is 0.864 bit/channel use ... SAVING
# Epoch 15: current MI estimate is 0.866 bit/channel use ... SAVING
# Epoch 16: current MI estimate is 0.866 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.001 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.268 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.978 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 1.107 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 1.117 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 1.127 bit/channel use ... SAVING
# Epoch 10: current MI estimate is 1.130 bit/channel use ... SAVING
# Epoch 15: current MI estimate is 1.137 bit/channel use ... SAVING
# Epoch 17: current MI estimate is 1.137 bit/channel use ... SAVING
# Epoch 18: current MI estimate is 1.145 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.004 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.293 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 0.948 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 1.292 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 1.387 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 1.416 bit/channel use ... SAVING
# Epoch 6: current MI estimate is 1.418 bit/channel use ... SAVING
# Epoch 7: current MI estimate is 1.426 bit/channel use ... SAVING
# Epoch 9: current MI estimate is 1.436 bit/channel use ... SAVING
# Epoch 16: current MI estimate is 1.442 bit/channel use ... SAVING
# Epoch 17: current MI estimate is 1.447 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.003 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.401 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 1.284 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 1.626 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 1.719 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 1.746 bit/channel use ... SAVING
# Epoch 6: current MI estimate is 1.749 bit/channel use ... SAVING
# Epoch 7: current MI estimate is 1.758 bit/channel use ... SAVING
# Epoch 8: current MI estimate is 1.769 bit/channel use ... SAVING
# Epoch 12: current MI estimate is 1.785 bit/channel use ... SAVING
# Epoch 0: current MI estimate is 0.002 bit/channel use ... SAVING
# Epoch 1: current MI estimate is 0.295 bit/channel use ... SAVING
# Epoch 2: current MI estimate is 1.150 bit/channel use ... SAVING
# Epoch 3: current MI estimate is 1.668 bit/channel use ... SAVING
# Epoch 4: current MI estimate is 1.913 bit/channel use ... SAVING
# Epoch 5: current MI estimate is 2.004 bit/channel use ... SAVING
# Epoch 6: current MI estimate is 2.074 bit/channel use ... SAVING
# Epoch 7: current MI estimate is 2.086 bit/channel use ... SAVING
# Epoch 8: current MI estimate is 2.098 bit/channel use ... SAVING
# Epoch 10: current MI estimate is 2.114 bit/channel use ... SAVING
# Epoch 13: current MI estimate is 2.116 bit/channel use ... SAVING
# Epoch 17: current MI estimate is 2.138 bit/channel use ... SAVING

# %%
# plotting options 
import matplotlib
font = {'size'   : 15}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)

plt.figure(figsize=(7,5))
plt.plot(esno_range, MI_ref)
plt.plot(esno_range, MI_MINE)
plt.xlim((-10,10))
plt.ylim((0,3))
plt.grid(True)
plt.legend([r'${I}(\mathsf{r};\mathsf{t}) = \frac{1}{2} \log_2\left(1+2\frac{E_{\mathrm{s}}}{N_0}\right)$','MINE'])
plt.title('MINE over the AWGN channel');
plt.xlabel(r'$E_{\mathrm{s}}/N_0$ (dB)')
plt.ylabel(r'$\\hat{I}(\mathsf{r};\mathsf{t})$ (bit/channel use)')

#plt.savefig('MINE_AWGN.pdf',bbox_inches='tight')
# Out:
# Text(0, 0.5, '$\\\\hat{I}(\\mathsf{r};\\mathsf{t})$ (bit/channel use)')
