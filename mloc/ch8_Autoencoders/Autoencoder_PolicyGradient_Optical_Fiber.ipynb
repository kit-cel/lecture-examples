# %% [markdown]
# #  Learn Modulation and Demodulation in Nonlinear Channels with Deep Neural Networks by Autoencoders and End-to-end Training
#
# This code is provided as supplementary material of the lecture Machine Learning and Optimization in Communications (MLOC).<br>
#
# This code illustrates
# * End-to-end-learning of modulation scheme and demodulator in a simple nonlinear channel model with time-varying batch size
# * Reinforcement Learning using policy learning (policy gradient method)
#
# This code is based on the the following paper:
# * Fayçal Ait Aoudia, Jakob Hoydis, "End-to-End Learning of Communications Systems Without a Channel Model" (https://arxiv.org/pdf/1804.02276.pdf).

# %%
import torch
import copy
import shutil
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from ipywidgets import interactive
import ipywidgets as widgets

# Search for a GPU and use CUDA if available, Apple Silicon (MPS) if present, otherwise CPU.
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if getattr(torch.backends, "mps", None) and torch.backends.mps.is_available() else "cpu")
print("We are using the following device for learning:",device)
# Out:
# We are using the following device for learning: cuda

# %% [markdown]
# ### Define Transmitter, Channel, Recevier and helper functions

# %% [markdown]
# This is the main neural network/Autoencoder with transmitter, channel and receiver. Transmitter and receiver each with ELU activation function. Note that the final layer does *not* use a `softmax` function, as this function is already included in the `CrossEntropyLoss`. <br>

# %%
class Transmitter(nn.Module):
    def __init__(self):
        super(Transmitter, self).__init__()
        # Define Transmitter Layer: Linear function, M input neurons (symbols), 2 output neurons (real and imaginary part)        
        # the matrix defines just a mapping between one-hot vectors and modulation symbols
        # Use Xavier initialization
        self.W = nn.Parameter(torch.empty(M,2))
        nn.init.xavier_uniform_(self.W)
        
    # Normalize channel input
    def normalize(self, x, P_in_lin):
        norm_factor = torch.mean(torch.sqrt(torch.sum(torch.square(x), 1)))/np.sqrt(P_in_lin)
        return norm_factor
    
    # Transmitter function, just a modulation followed by normalization
    def forward(self, x, P_in_lin):
        # compute output
        norm_factor = self.normalize(self.W, P_in_lin)
        out = torch.matmul(x, self.W/norm_factor)
        return out
        
    
class Receiver(nn.Module):
    def __init__(self, hidden_neurons_RX):
        super(Receiver, self).__init__()
        
        # Define Receiver Layer: Linear function, 2 input neurons (real and imaginary part), M output neurons (symbols)
        self.fcR1 = nn.Linear(2,hidden_neurons_RX[0]) 
        self.fcR2 = nn.Linear(hidden_neurons_RX[0], hidden_neurons_RX[1]) 
        self.fcR3 = nn.Linear(hidden_neurons_RX[1], hidden_neurons_RX[2]) 
        self.fcR4 = nn.Linear(hidden_neurons_RX[2], M) 

        # Non-linearity (used in transmitter and receiver)
        self.activation_function = nn.ELU()      

    # Receiver neural network    
    def forward(self, x):
        out = self.activation_function(self.fcR1(x))
        out = self.activation_function(self.fcR2(out))
        out = self.activation_function(self.fcR3(out))
        logits = self.fcR4(out)
        return logits

# %%
# Optical fiber channel model
def channel_model(x, L, Kstep, gamma):
    # simulate the channel
    for i in range(Kstep):
        power = torch.norm(x, dim=1) ** 2
        rotcoff = (L / Kstep) * gamma * power

        # rotation matrix corresponding to exp(1j*rotcoff)        
        temp = torch.stack([x[:,0] * torch.cos(rotcoff) - x[:,1]*torch.sin(rotcoff), x[:,0]*torch.sin(rotcoff)+x[:,1]*torch.cos(rotcoff)], dim=1)        
        x = torch.add(temp, sigma_n*torch.randn(len(x),2).to(device))
    return x

# %%
# helper function to compute the symbol error rate
def SER(predictions, labels):
    return (np.sum(np.argmax(predictions, 1) != labels) / predictions.shape[0])

# %% [markdown]
# ### Parameter and Training
# Here, we define the parameters of the neural network and training, generate the validation set and a helping set to show the decision regions

# %%
# number of symbols
M = 16

P_in_dBm = 6 # 6dBm input power
P_in_lin = 10**((P_in_dBm-30)/10)

SNR = 17 # dB

# channel parameter
L = 500                                                 # in [km]
gamma = 1.27                                            # Nonlinear Kerr-Coefficient in [W/km]
Kstep = 50 # number of steps used in the channel model
# noise variance per step   
sigma_n = np.sqrt(P_in_lin* 10**(-SNR/10) / Kstep / 2)

# validation set. Training examples are generated on the fly
N_valid = 100000

# variance of policy vector
sigma_p = np.sqrt(0.02*P_in_lin)

# number of neurons in hidden layers at receiver
hidden_neurons_RX_1 = 50
hidden_neurons_RX_2 = 50
hidden_neurons_RX_3 = 50
hidden_neurons_RX = [hidden_neurons_RX_1, hidden_neurons_RX_2, hidden_neurons_RX_3]

# Generate Validation Data
y_valid = np.random.randint(M,size=N_valid)
y_valid_onehot = np.eye(M)[y_valid]

# meshgrid for plotting
# assume that the worst case constellation is the one where all points lie on a straight line starting at the center and then are spreaded equidistantly. In this case, this is the scaling factor of the constellation points and we assume that there is an (M+1)th point which defines ext_max 
ext_max = 1.8*np.sqrt(P_in_lin)
mgx,mgy = np.meshgrid(np.linspace(-ext_max,ext_max,400), np.linspace(-ext_max,ext_max,400))
meshgrid = np.column_stack((np.reshape(mgx,(-1,1)),np.reshape(mgy,(-1,1))))

# %% [markdown]
# Now, carry out the training as such. First initialize the variables and then loop through the training. Here, the epochs are not defined in the classical way, as we do not have a training set per se. We generate new data on the fly and never reuse data.
#
# First, we train the receiver for a given transmitter. Then we calculate per-example-losses and use the policy gradient method to find the coefficients of the transmitter for a given receiver.

# %%
model_tx = Transmitter()
model_tx.to(device)

model_rx = Receiver(hidden_neurons_RX)
model_rx.to(device)

softmax = nn.Softmax(dim=1)

# Cross Entropy loss for RX-optimization
loss_fn = nn.CrossEntropyLoss()
loss_tx = nn.CrossEntropyLoss(reduction='none')


# Adam Optimizers for TX and RX
optimizer_tx = optim.Adam(model_tx.parameters(), lr=1e-3)  
optimizer_rx = optim.Adam(model_rx.parameters(), lr=1e-2)

# Training parameters
num_epochs = 120
batches_per_epoch = 100

# Vary batch size during training
batch_size_per_epoch = np.linspace(100,10000,num=num_epochs, dtype=np.int16)

validation_SERs = np.zeros(num_epochs)
validation_received = []
decision_region_evolution = []
constellations = []
best_SER = np.inf
best_epoch = 0


print('Start Training')
for epoch in range(num_epochs):
       
    batch_labels = torch.empty(batch_size_per_epoch[epoch], device=device)

    # Optimize Receiver for a given transmitter, standard learning of the receiver parameters
    for step in range(batches_per_epoch):
        # Generate training data: In most cases, you have a dataset and do not generate a training dataset during training loop
        # sample new mini-batch directory on the GPU (if available)        
        batch_labels.random_(M)
        batch_labels_onehot = torch.zeros(int(batch_size_per_epoch[epoch]), M, device=device)
        batch_labels_onehot[range(batch_labels_onehot.shape[0]), batch_labels.long()]=1

        # Propagate (training) data through the net
        encoded = model_tx(batch_labels_onehot, P_in_lin)
                
        # channel model
        received = channel_model(encoded, L, Kstep, gamma)
        
        # receiver
        logits = model_rx(received)

        # compute loss
        loss = loss_fn(logits, batch_labels.long())

        # compute gradients
        loss.backward()
        
        # Adapt weights
        optimizer_rx.step()
        
        # reset gradients
        optimizer_rx.zero_grad()

        
    # Optimize Transmitter using the policy gradient method
    for step in range(batches_per_epoch):
        # Generate training data: In most cases, you have a dataset and do not generate a training dataset during training loop
        # sample new mini-batch directory on the GPU (if available)        
        batch_labels.random_(M)
        batch_labels_onehot = torch.zeros(int(batch_size_per_epoch[epoch]), M, device=device)
        batch_labels_onehot[range(batch_labels_onehot.shape[0]), batch_labels.long()]=1

        # Propagate (training) data through the net
        tx_output = model_tx(batch_labels_onehot, P_in_lin)
        
        # apply policy, which is Gaussian noise
        noise = (sigma_p / np.sqrt(2)) * torch.randn_like(tx_output).to(device)               
        encoded = np.sqrt(1-(sigma_p**2))*tx_output.detach() + noise      
          
        # channel model
        encoded_clone = encoded.clone().detach()
        received = channel_model(encoded_clone, L, Kstep, gamma)
        
        logits = model_rx(received)
        
        # compute per example losses ... detach from graph so that the gradient is not computed        
        per_example_losses = loss_tx(logits, batch_labels.long()).clone().detach()
        
        # policy gradient loss
        pg_loss = (1/batch_size_per_epoch[epoch])*torch.sum(
            per_example_losses * torch.log(
                (1/(np.pi * sigma_p**2))*torch.exp(-1/(sigma_p**2)*torch.sum(torch.square(
                    encoded_clone-np.sqrt(1-(sigma_p**2))*tx_output), 1)
                )
            )
        )   
        
        # compute gradients
        pg_loss.backward()
        
        # Adapt weights
        optimizer_tx.step()
        
        # reset gradients
        optimizer_tx.zero_grad()
        
        
    # compute validation SER
    with torch.no_grad():
        encoded_valid = model_tx(torch.Tensor(y_valid_onehot).to(device),P_in_lin)
        received_valid = channel_model(encoded_valid, L, Kstep, gamma)
        out_valid = softmax(model_rx(received_valid))
        validation_SERs[epoch] = SER(out_valid.detach().cpu().numpy().squeeze(), y_valid)
        if validation_SERs[epoch] < best_SER:
            best_model_tx_state_dict = copy.deepcopy(model_tx.state_dict())
            best_model_rx_state_dict = copy.deepcopy(model_rx.state_dict())
            best_SER = validation_SERs[epoch]
            best_epoch = epoch
            print('Validation SER after epoch %d: %f (loss %1.8f, pg_loss %1.8f) ... SAVING' % (epoch, validation_SERs[epoch], loss.detach().cpu().numpy(), pg_loss.detach().cpu().numpy()))
        else:
            print('Validation SER after epoch %d: %f (loss %1.8f, pg_loss %1.8f)' % (epoch, validation_SERs[epoch], loss.detach().cpu().numpy(), pg_loss.detach().cpu().numpy()))

        # calculate and store received validation data
        encoded = model_tx(torch.Tensor(y_valid_onehot).to(device),P_in_lin)
        received = channel_model(encoded, L, Kstep, gamma)
        validation_received.append(received.detach().cpu().numpy())

        # calculate and store constellation
        encoded = model_tx(torch.eye(M).to(device),P_in_lin)
        constellations.append(encoded.detach().cpu().numpy())

        # store decision region for generating the animation
        mesh_prediction = softmax(model_rx(torch.Tensor(meshgrid).to(device)))
        decision_region_evolution.append(0.195*mesh_prediction.detach().cpu().numpy() + 0.4)
    
model_tx.load_state_dict(best_model_tx_state_dict)
model_rx.load_state_dict(best_model_rx_state_dict)

print('Training finished')
print(model_tx.W)
# Out:
# Start Training
# Validation SER after epoch 0: 0.415290 (loss 0.96111292, pg_loss 18.63900757) ... SAVING
# Validation SER after epoch 1: 0.376540 (loss 0.59928000, pg_loss 22.16411209) ... SAVING
# Validation SER after epoch 2: 0.210210 (loss 0.52322680, pg_loss 15.11357784) ... SAVING
# Validation SER after epoch 3: 0.185930 (loss 0.39128512, pg_loss 12.31682205) ... SAVING
# Validation SER after epoch 4: 0.144650 (loss 0.33871287, pg_loss 11.34415340) ... SAVING
# Validation SER after epoch 5: 0.125640 (loss 0.30558121, pg_loss 8.37045383) ... SAVING
# Validation SER after epoch 6: 0.117030 (loss 0.24431314, pg_loss 9.78733921) ... SAVING
# Validation SER after epoch 7: 0.103550 (loss 0.28115076, pg_loss 9.44725132) ... SAVING
# Validation SER after epoch 8: 0.103680 (loss 0.22987624, pg_loss 10.77321148)
# Validation SER after epoch 9: 0.094880 (loss 0.24164267, pg_loss 8.92622662) ... SAVING
# Validation SER after epoch 10: 0.098370 (loss 0.27123585, pg_loss 8.65590096)
# Validation SER after epoch 11: 0.083840 (loss 0.22984397, pg_loss 9.21430683) ... SAVING
# Validation SER after epoch 12: 0.080000 (loss 0.22882856, pg_loss 8.75529003) ... SAVING
# Validation SER after epoch 13: 0.072980 (loss 0.19686909, pg_loss 8.58256817) ... SAVING
# Validation SER after epoch 14: 0.073850 (loss 0.20400786, pg_loss 7.16923618)
# Validation SER after epoch 15: 0.087490 (loss 0.19347735, pg_loss 8.43150330)
# Validation SER after epoch 16: 0.068450 (loss 0.16901155, pg_loss 8.43079758) ... SAVING
# Validation SER after epoch 17: 0.067190 (loss 0.18086545, pg_loss 8.79874611) ... SAVING
# Validation SER after epoch 18: 0.071450 (loss 0.20545965, pg_loss 8.55559540)
# Validation SER after epoch 19: 0.058230 (loss 0.18096349, pg_loss 6.52544451) ... SAVING
# Validation SER after epoch 20: 0.056300 (loss 0.14519119, pg_loss 7.06243372) ... SAVING
# Validation SER after epoch 21: 0.058070 (loss 0.15163930, pg_loss 6.68277788)
# Validation SER after epoch 22: 0.054880 (loss 0.14303192, pg_loss 7.69982290) ... SAVING
# Validation SER after epoch 23: 0.065300 (loss 0.13941856, pg_loss 7.78910065)
# Validation SER after epoch 24: 0.054190 (loss 0.13783319, pg_loss 7.05161190) ... SAVING
# Validation SER after epoch 25: 0.052340 (loss 0.14070129, pg_loss 6.37375927) ... SAVING
# Validation SER after epoch 26: 0.053650 (loss 0.14449182, pg_loss 5.33135176)
# Validation SER after epoch 27: 0.051960 (loss 0.16016988, pg_loss 6.39579201) ... SAVING
# Validation SER after epoch 28: 0.051380 (loss 0.14869855, pg_loss 5.92190218) ... SAVING
# Validation SER after epoch 29: 0.052440 (loss 0.13472010, pg_loss 5.92198801)
# Validation SER after epoch 30: 0.049290 (loss 0.15179290, pg_loss 6.11157274) ... SAVING
# Validation SER after epoch 31: 0.053590 (loss 0.14180751, pg_loss 5.90519476)
# Validation SER after epoch 32: 0.051710 (loss 0.13560580, pg_loss 5.20825529)
# Validation SER after epoch 33: 0.046470 (loss 0.12637578, pg_loss 5.95524025) ... SAVING
# Validation SER after epoch 34: 0.050170 (loss 0.12697212, pg_loss 5.79021788)
# Validation SER after epoch 35: 0.050720 (loss 0.12736604, pg_loss 5.36621666)
# Validation SER after epoch 36: 0.051510 (loss 0.13250631, pg_loss 5.94790983)
# Validation SER after epoch 37: 0.048310 (loss 0.11939694, pg_loss 5.96211243)
# Validation SER after epoch 38: 0.051760 (loss 0.14660606, pg_loss 4.61607647)
# Validation SER after epoch 39: 0.048070 (loss 0.12342469, pg_loss 4.96092367)
# Validation SER after epoch 40: 0.045900 (loss 0.11765125, pg_loss 5.32838154) ... SAVING
# Validation SER after epoch 41: 0.045880 (loss 0.13781518, pg_loss 4.99134827) ... SAVING
# Validation SER after epoch 42: 0.047030 (loss 0.11568038, pg_loss 5.22308922)
# Validation SER after epoch 43: 0.046850 (loss 0.12720175, pg_loss 4.89170742)
# Validation SER after epoch 44: 0.045870 (loss 0.13059133, pg_loss 4.90872908) ... SAVING
# Validation SER after epoch 45: 0.043690 (loss 0.11910309, pg_loss 4.85214472) ... SAVING
# Validation SER after epoch 46: 0.045610 (loss 0.12764448, pg_loss 4.58186245)
# Validation SER after epoch 47: 0.044450 (loss 0.11588914, pg_loss 4.92143917)
# Validation SER after epoch 48: 0.042050 (loss 0.12114375, pg_loss 4.77928972) ... SAVING
# Validation SER after epoch 49: 0.044040 (loss 0.11353672, pg_loss 4.85013151)
# Validation SER after epoch 50: 0.042150 (loss 0.10761072, pg_loss 4.52408791)
# Validation SER after epoch 51: 0.041770 (loss 0.10854439, pg_loss 4.29528666) ... SAVING
# Validation SER after epoch 52: 0.041700 (loss 0.10815412, pg_loss 4.97758722) ... SAVING
# Validation SER after epoch 53: 0.044850 (loss 0.10751241, pg_loss 4.50572920)
# Validation SER after epoch 54: 0.040050 (loss 0.10845574, pg_loss 4.37085199) ... SAVING
# Validation SER after epoch 55: 0.042810 (loss 0.10816689, pg_loss 4.57501650)
# Validation SER after epoch 56: 0.041500 (loss 0.11340328, pg_loss 4.64146566)
# Validation SER after epoch 57: 0.042030 (loss 0.11168235, pg_loss 4.45345736)
# Validation SER after epoch 58: 0.041340 (loss 0.12217790, pg_loss 4.42329884)
# Validation SER after epoch 59: 0.041400 (loss 0.11457548, pg_loss 4.49392080)
# Validation SER after epoch 60: 0.041820 (loss 0.09832828, pg_loss 4.44682360)
# Validation SER after epoch 61: 0.043050 (loss 0.11156586, pg_loss 4.25244236)
# Validation SER after epoch 62: 0.041380 (loss 0.10571535, pg_loss 4.02196836)
# Validation SER after epoch 63: 0.040830 (loss 0.11698122, pg_loss 4.12173891)
# Validation SER after epoch 64: 0.040260 (loss 0.09997649, pg_loss 4.23513842)
# Validation SER after epoch 65: 0.040090 (loss 0.12552649, pg_loss 4.44340992)
# Validation SER after epoch 66: 0.042080 (loss 0.10797070, pg_loss 4.36429024)
# Validation SER after epoch 67: 0.040010 (loss 0.09943460, pg_loss 4.34513760) ... SAVING
# Validation SER after epoch 68: 0.041480 (loss 0.11291676, pg_loss 4.73721838)
# Validation SER after epoch 69: 0.040920 (loss 0.10905761, pg_loss 4.37715435)
# Validation SER after epoch 70: 0.039670 (loss 0.09937374, pg_loss 4.51604700) ... SAVING
# Validation SER after epoch 71: 0.040820 (loss 0.11418767, pg_loss 4.57831287)
# Validation SER after epoch 72: 0.039270 (loss 0.10330988, pg_loss 4.53502893) ... SAVING
# Validation SER after epoch 73: 0.038870 (loss 0.11008807, pg_loss 4.42049122) ... SAVING
# Validation SER after epoch 74: 0.036560 (loss 0.10368977, pg_loss 4.24892235) ... SAVING
# Validation SER after epoch 75: 0.036950 (loss 0.08447230, pg_loss 4.41139650)
# Validation SER after epoch 76: 0.036360 (loss 0.09120759, pg_loss 4.01158857) ... SAVING
# Validation SER after epoch 77: 0.035200 (loss 0.08585555, pg_loss 4.19838905) ... SAVING
# Validation SER after epoch 78: 0.032810 (loss 0.08292712, pg_loss 4.00157499) ... SAVING
# Validation SER after epoch 79: 0.030340 (loss 0.08822238, pg_loss 3.97608757) ... SAVING
# Validation SER after epoch 80: 0.029720 (loss 0.09255432, pg_loss 4.24686718) ... SAVING
# Validation SER after epoch 81: 0.030350 (loss 0.08149879, pg_loss 4.32515955)
# Validation SER after epoch 82: 0.029300 (loss 0.08035953, pg_loss 4.42382097) ... SAVING
# Validation SER after epoch 83: 0.029400 (loss 0.07848876, pg_loss 4.14806890)
# Validation SER after epoch 84: 0.029000 (loss 0.08090798, pg_loss 3.99741435) ... SAVING
# Validation SER after epoch 85: 0.027340 (loss 0.07029524, pg_loss 3.86673713) ... SAVING
# Validation SER after epoch 86: 0.029760 (loss 0.07244034, pg_loss 4.42550850)
# Validation SER after epoch 87: 0.027700 (loss 0.08096362, pg_loss 3.98197722)
# Validation SER after epoch 88: 0.029980 (loss 0.07756101, pg_loss 4.36379671)
# Validation SER after epoch 89: 0.029460 (loss 0.07655916, pg_loss 3.98907304)
# Validation SER after epoch 90: 0.029480 (loss 0.08448020, pg_loss 3.84683037)
# Validation SER after epoch 91: 0.030050 (loss 0.08187066, pg_loss 4.07879925)
# Validation SER after epoch 92: 0.031370 (loss 0.08679894, pg_loss 4.19140148)
# Validation SER after epoch 93: 0.030510 (loss 0.08332774, pg_loss 4.06907606)
# Validation SER after epoch 94: 0.030460 (loss 0.08341272, pg_loss 3.94047427)
# Validation SER after epoch 95: 0.030180 (loss 0.07927334, pg_loss 4.14829922)
# Validation SER after epoch 96: 0.031400 (loss 0.08177050, pg_loss 4.09504461)
# Validation SER after epoch 97: 0.028610 (loss 0.08292988, pg_loss 4.04307604)
# Validation SER after epoch 98: 0.030110 (loss 0.07241142, pg_loss 4.13487196)
# Validation SER after epoch 99: 0.029390 (loss 0.06842445, pg_loss 3.91126561)
# Validation SER after epoch 100: 0.028440 (loss 0.08292574, pg_loss 4.09725142)
# Validation SER after epoch 101: 0.027240 (loss 0.07386918, pg_loss 4.29705572) ... SAVING
# Validation SER after epoch 102: 0.028250 (loss 0.07058876, pg_loss 4.36707497)
# Validation SER after epoch 103: 0.027040 (loss 0.07184590, pg_loss 4.03494644) ... SAVING
# Validation SER after epoch 104: 0.026120 (loss 0.06917968, pg_loss 4.10457706) ... SAVING
# Validation SER after epoch 105: 0.029730 (loss 0.07533111, pg_loss 4.60244703)
# Validation SER after epoch 106: 0.025610 (loss 0.07206408, pg_loss 4.24250984) ... SAVING
# Validation SER after epoch 107: 0.026090 (loss 0.07544443, pg_loss 4.39667654)
# Validation SER after epoch 108: 0.025150 (loss 0.07134865, pg_loss 4.33063316) ... SAVING
# Validation SER after epoch 109: 0.025140 (loss 0.07114626, pg_loss 4.22652245) ... SAVING
# Validation SER after epoch 110: 0.025250 (loss 0.07119317, pg_loss 4.10998297)
# Validation SER after epoch 111: 0.024820 (loss 0.07148983, pg_loss 3.74373507) ... SAVING
# Validation SER after epoch 112: 0.024390 (loss 0.06423841, pg_loss 4.43961811) ... SAVING
# Validation SER after epoch 113: 0.024450 (loss 0.06616883, pg_loss 3.86931825)
# Validation SER after epoch 114: 0.024510 (loss 0.05988219, pg_loss 4.11710835)
# Validation SER after epoch 115: 0.024220 (loss 0.06736222, pg_loss 4.05478716) ... SAVING
# Validation SER after epoch 116: 0.022330 (loss 0.06152660, pg_loss 4.36421871) ... SAVING
# Validation SER after epoch 117: 0.024190 (loss 0.06472101, pg_loss 4.18268156)
# Validation SER after epoch 118: 0.023210 (loss 0.06354180, pg_loss 4.02334213)
# Validation SER after epoch 119: 0.021410 (loss 0.06679955, pg_loss 3.99223232) ... SAVING
# Training finished
# Parameter containing:
# tensor([[-0.1537,  0.1202],
#         [ 0.0072,  0.4471],
#         [-0.0452, -0.2459],
#         [-0.2674, -0.0457],
#         [ 0.1305, -0.0657],
#         [-0.7564,  0.1468],
#         [-0.3334,  0.3625],
#         [ 0.5416,  0.0523],
#         [ 0.0649,  0.3075],
#         [ 0.2212, -0.2524],
#         [-0.4919,  0.4491],
#         [ 0.4040, -0.0583],
#         [-0.3839, -0.1857],
#         [ 0.1120, -0.5756],
#         [ 0.1645,  0.1457],
#         [-0.1838, -0.4543]], device='cuda:0', requires_grad=True)
# Validation SER after epoch 105: 0.039800 (loss 0.10770185, pg_loss 4.29549313)
# Validation SER after epoch 106: 0.040850 (loss 0.10618494, pg_loss 4.13391495)
# Validation SER after epoch 107: 0.042550 (loss 0.10597027, pg_loss 4.28672934)
# Validation SER after epoch 108: 0.041880 (loss 0.10748333, pg_loss 4.15152550)
# Validation SER after epoch 109: 0.041980 (loss 0.11367940, pg_loss 4.12118864)
# Validation SER after epoch 110: 0.041620 (loss 0.10433889, pg_loss 4.26844931)
# Validation SER after epoch 111: 0.040960 (loss 0.11059269, pg_loss 4.11457586)
# Validation SER after epoch 112: 0.041560 (loss 0.11058690, pg_loss 4.21547461)
# Validation SER after epoch 113: 0.039430 (loss 0.11201237, pg_loss 3.90708876)
# Validation SER after epoch 114: 0.041000 (loss 0.10515636, pg_loss 4.09803343)
# Validation SER after epoch 115: 0.039470 (loss 0.10729159, pg_loss 4.06426096)
# Validation SER after epoch 116: 0.038710 (loss 0.10039364, pg_loss 4.11216688)
# Validation SER after epoch 117: 0.038700 (loss 0.10223638, pg_loss 4.08842564)
# Validation SER after epoch 118: 0.037350 (loss 0.09859591, pg_loss 4.02379560)
# Validation SER after epoch 119: 0.039290 (loss 0.11038115, pg_loss 4.31275129)
# Training finished
# Parameter containing:
# tensor([[ 0.2570, -0.1464],
#         [ 0.2765,  0.4240],
#         [ 0.5681,  0.4767],
#         [-0.0669,  0.0261],
#         [-0.0092,  0.2503],
#         [-0.2195,  0.1450],
#         [-0.1344, -0.1313],
#         [-0.0107, -0.2744],
#         [-1.5414,  1.6573],
#         [-0.3274,  0.3347],
#         [ 0.1425,  0.0857],
#         [ 0.0978, -0.1049],
#         [-0.2709, -0.3714],
#         [-0.3408, -0.1030],
#         [ 0.3243,  0.1754],
#         [ 0.2843, -0.4064]], device='cuda:0', requires_grad=True)

# %% [markdown]
# ### Evaluation
# Plot decision region and scatter plot of the validation set. Note that the validation set is **only** used for computing SERs and plotting, there is no feedback towards the training!

# %%
# find minimum SER from validation set
min_SER_iter = np.argmin(validation_SERs)
print('Minimum SER obtained: %1.5f' % validation_SERs[min_SER_iter])

ext_max_plot = 1.05*max(max(abs(validation_received[min_SER_iter][:,0])), max(abs(validation_received[min_SER_iter][:,1])))
# Out:
# Minimum SER obtained: 0.02141

# %%
base = matplotlib.colormaps["tab20"].resampled(M)
color_list = base.colors
new_color_list = [[t/2 + 0.5 for t in color_list[k]] for k in range(len(color_list))]

# %matplotlib inline
plt.figure(figsize=(19,9.5))
font = {'size'   : 14}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)
    
plt.subplot(121)
plt.scatter(constellations[min_SER_iter][:,0], constellations[min_SER_iter][:,1], c=range(M), cmap='tab20',s=50)
plt.axis('scaled')
plt.xlabel(r'$\Re\{t\}$',fontsize=18)
plt.ylabel(r'$\Im\{t\}$',fontsize=18)
plt.xlim((-ext_max,ext_max))
plt.ylim((-ext_max,ext_max))
plt.grid(which='both')
plt.title('Constellation diagram (transmit symbols)',fontsize=18)

plt.subplot(122)
decision_scatter = np.argmax(decision_region_evolution[min_SER_iter], 1)
plt.scatter(meshgrid[:,0], meshgrid[:,1], c=decision_scatter, cmap=matplotlib.colors.ListedColormap(colors=new_color_list),s=4)
plt.scatter(constellations[min_SER_iter][:,0], constellations[min_SER_iter][:,1], c=range(M), cmap='tab20',s=50)
plt.axis('scaled')
plt.xlim((-ext_max,ext_max))
plt.ylim((-ext_max,ext_max))
plt.xlabel(r'$\Re\{t/r\}$',fontsize=18)
plt.ylabel(r'$\Im\{t/r\}$',fontsize=18)
plt.title('Constellation diagram (transmit symbols) with decision regions',fontsize=18)


plt.savefig('PGAE_Optical_NN_M%d_Pin%1.2f_SNR%1.2f_const.pdf' % (M,P_in_dBm,SNR),bbox_inches='tight')
# Out:
# /tmp/ipykernel_152/2467053243.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   base = plt.cm.get_cmap(cmap)

# %%
base = matplotlib.colormaps["tab20"].resampled(M)
color_list = base.colors
new_color_list = [[t/2 + 0.5 for t in color_list[k]] for k in range(len(color_list))]

# %matplotlib inline
plt.figure(figsize=(19,9.5))
font = {'size'   : 14}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)
    

plt.subplot(121)
#plt.contourf(mgx,mgy,decision_region_evolution[-1].reshape(mgy.shape).T,cmap='coolwarm',vmin=0.3,vmax=0.7)
plt.scatter(validation_received[min_SER_iter][:,0], validation_received[min_SER_iter][:,1], c=y_valid, cmap='tab20',s=4)
plt.axis('scaled')
plt.xlabel(r'$\Re\{r\}$',fontsize=18)
plt.ylabel(r'$\Im\{r\}$',fontsize=18)
plt.xlim((-ext_max,ext_max))
plt.ylim((-ext_max,ext_max))
plt.title('Received symbols',fontsize=18)

plt.subplot(122)
decision_scatter = np.argmax(decision_region_evolution[min_SER_iter], 1)
plt.scatter(meshgrid[:,0], meshgrid[:,1], c=decision_scatter, cmap=matplotlib.colors.ListedColormap(colors=new_color_list),s=4)
plt.scatter(validation_received[min_SER_iter][0:4000,0], validation_received[min_SER_iter][0:4000,1], c=y_valid[0:4000], cmap='tab20',s=4)
plt.axis('scaled')
plt.xlim((-ext_max,ext_max))
plt.ylim((-ext_max,ext_max))
plt.xlabel(r'$\Re\{r\}$',fontsize=18)
plt.ylabel(r'$\Im\{r\}$',fontsize=18)
plt.title('Received sybmols with decision regions',fontsize=18)

plt.savefig('PGAE_Optical_NN_M%d_Pin%1.2f_SNR%1.2f_noisy.pdf' % (M,P_in_dBm,SNR),bbox_inches='tight')
# Out:
# /tmp/ipykernel_152/695373568.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   base = plt.cm.get_cmap(cmap)

# %%
# %matplotlib notebook
# %matplotlib notebook

base = matplotlib.colormaps["tab20"].resampled(M)
color_list = base.colors
new_color_list = [[t/2 + 0.5 for t in color_list[k]] for k in range(len(color_list))]

from matplotlib import animation, rc
from matplotlib.animation import PillowWriter # Disable if you don't want to save any GIFs.

font = {'size'   : 18}
plt.rc('font', **font)
plt.rc('text', usetex=True if shutil.which('latex') else False)

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)

ax.axis('scaled')

written = True
def animate(i):
    ax.clear()
    decision_scatter = np.argmax(decision_region_evolution[i], 1)
    
    ax.scatter(meshgrid[:,0], meshgrid[:,1], c=decision_scatter, cmap=matplotlib.colors.ListedColormap(colors=new_color_list),s=4, marker='s')
    ax.scatter(constellations[i][:,0], constellations[i][:,1], c=range(M), cmap='tab20',s=50)
    ax.scatter(validation_received[i][0:4000,0], validation_received[i][0:4000,1], c=y_valid[0:4000], cmap='tab20',s=4)
    ax.set_xlim(( -ext_max, ext_max))
    ax.set_ylim(( -ext_max, ext_max))

    ax.set_xlabel(r'$\Re\{r\}$',fontsize=18)
    ax.set_ylabel(r'$\Im\{r\}$',fontsize=18)

anim = animation.FuncAnimation(fig, animate, frames=num_epochs-1, interval=200, blit=False)
plt.show()
anim.save('PGAE_Optical_NN_M%d_Pin%1.2f_SNR%1.2f_anim.gif' % (M,P_in_dBm,SNR), writer=PillowWriter(fps=5))
# Out:
# /tmp/ipykernel_152/2461070531.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   base = plt.cm.get_cmap(cmap)
# <div id='446d8a67-6342-431e-ae27-538c740ed776'></div>
